# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotikashyap85399-tech/Image-classification/blob/main/ColumnTransfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/covid_toy.csv')

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['has_covid']),df['has_covid'],
                                                 test_size=0.2)

# %%
X_train
# Out:
#     age  gender  fever cough       city
# 67   65    Male   99.0  Mild  Bangalore
# 93   27    Male  100.0  Mild    Kolkata
# 37   55    Male  100.0  Mild    Kolkata
# 45   72    Male   99.0  Mild  Bangalore
# 26   19  Female  100.0  Mild    Kolkata
# ..  ...     ...    ...   ...        ...
# 79   48  Female  103.0  Mild    Kolkata
# 40   49  Female  102.0  Mild      Delhi
# 23   80  Female   98.0  Mild      Delhi
# 10   75  Female    NaN  Mild      Delhi
# 95   12  Female  104.0  Mild  Bangalore
#
# [80 rows x 5 columns]

# %% [markdown]
# #### **1.Aam Zindagi**

# %%
si = SimpleImputer() #simple imputer on fever
X_train_fever = si.fit_transform(X_train[['fever']])
X_test_fever = si.fit_transform(X_test[['fever']])
X_train_fever.shape
# Out:
# (80, 1)

# %%
oe = OrdinalEncoder(categories=[['Mild','Strong']]) #ordinal encoder on cough
X_train_cough = oe.fit_transform(X_train[['cough']])
X_test_cough = oe.fit_transform(X_test[['cough']])

X_train_cough.shape
# Out:
# (80, 1)

# %%
ohe = OneHotEncoder(drop='first') #onehotencoding on gender,city
X_train_gender_city = ohe.fit_transform(X_train[['gender','city']])
X_test_gender_city = ohe.transform(X_test[['gender','city']])

X_train_gender_city.shape
# Out:
# (80, 4)

# %%
X_train_age = X_train.drop(columns=['gender','fever','cough','city']).values
X_test_age = X_test.drop(columns=['gender','fever','cough','city']).values
X_train_age.shape
# Out:
# (80, 1)

# %%
X_train_transformed = np.concatenate((X_train_age,X_train_fever,X_train_gender_city.toarray(),X_train_cough),axis=1)
X_test_transformed = np.concatenate((X_test_age,X_test_fever,X_test_gender_city.toarray(),X_test_cough),axis=1)
X_train_transformed
# Out:
# array([[ 65.        ,  99.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,   0.        ],
#        [ 27.        , 100.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,   0.        ],
#        [ 55.        , 100.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,   0.        ],
#        [ 72.        ,  99.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,   0.        ],
#        [ 19.        , 100.        ,   0.        ,   0.        ,
#           1.        ,   0.        ,   0.        ],
#        [ 64.        , 101.        ,   0.        ,   1.        ,
#           0.        ,   0.        ,   0.        ],
#        [ 22.        ,  99.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,   0.        ],
#        [ 16.        , 104.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,   0.        ],
# ...

# %% [markdown]
# #### **Mentos zindagi**

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer = ColumnTransformer(transformers=[
    ('tnf1', SimpleImputer(),['fever']),
    ('tnf2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']),
    ('tnf3',OneHotEncoder(drop='first'),['gender','city'])
],remainder='passthrough')

# %%
transformer.fit_transform(X_train)
# Out:
# array([[ 99.        ,   0.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  65.        ],
#        [100.        ,   0.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,  27.        ],
#        [100.        ,   0.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,  55.        ],
#        [ 99.        ,   0.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  72.        ],
#        [100.        ,   0.        ,   0.        ,   0.        ,
#           1.        ,   0.        ,  19.        ],
#        [101.        ,   0.        ,   0.        ,   1.        ,
#           0.        ,   0.        ,  64.        ],
#        [ 99.        ,   0.        ,   0.        ,   0.        ,
#           0.        ,   0.        ,  22.        ],
#        [104.        ,   0.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,  16.        ],
# ...

# %%
transformer.transform(X_test).shape
# Out:
# (20, 7)
